# %%
import json
import os

# %%
data = json.load(open('sample_data.json'))

# %%
docid, doc = list(data.items())[1]

# %%
for k, v in doc.items():
    print(k, json.dumps(v[0], indent=2) if isinstance(v, list) and len(v) > 0 else json.dumps(list(v.values())[0], indent=2) if v is isinstance(v, dict) else None)
# Out:
# strategy_1 {
#   "init_question": "What committed a crime before officials committed a crime",
#   "answer": "officials",
#   "events": [
#     {
#       "id": "scenario_en_62-E2",
#       "event_type": "GenericCrime.GenericCrime.GenericCrime",
#       "trigger": {
#         "start": 1258,
#         "end": 1259,
#         "text": "violations",
#         "sent_idx": 21
#       },
#       "arguments": [
#         {
#           "entity_id": "scenario_en_62-T281",
#           "role": "Perpetrator",
#           "text": "officials"
#         }
#       ]
#     },
#     {
#       "id": "scenario_en_62-E2",
#       "event_type": "GenericCrime.GenericCrime.GenericCrime",
#       "trigger": {
#         "start": 1258,
#         "end": 1259,
#         "text": "violations",
#         "sent_idx": 21
#       },
#       "arguments": [
#         {
#           "entity_id": "scenario_en_62-T281",
#           "role": "Perpetrator",
#           "text": "officials"
#         }
#       ]
#     }
#   ],
# ...

# %%
doc['strategy_4']
# Out:
# {'Contact.Contact.Broadcast': [{'id': 'road_ied_8-E3',
#    'event_type': 'Contact.Contact.Broadcast',
#    'trigger': {'start': 71, 'end': 72, 'text': 'reported', 'sent_idx': 2},
#    'arguments': [{'entity_id': 'road_ied_8-T17',
#      'role': 'Communicator',
#      'text': 'Al-Monitor'}]},
#   {'id': 'road_ied_8-E8',
#    'event_type': 'Contact.Contact.Broadcast',
#    'trigger': {'start': 232, 'end': 233, 'text': 'reported', 'sent_idx': 9},
#    'arguments': [{'entity_id': 'road_ied_8-T55',
#      'role': 'Communicator',
#      'text': 'Al-Monitor'}]},
#   {'id': 'road_ied_8-E10',
#    'event_type': 'Contact.Contact.Broadcast',
#    'trigger': {'start': 432, 'end': 433, 'text': 'reported', 'sent_idx': 14},
#    'arguments': [{'entity_id': 'road_ied_8-T103',
#      'role': 'Communicator',
#      'text': 'Al-Monitor'}]},
#   {'id': 'road_ied_8-E11',
#    'event_type': 'Contact.Contact.Broadcast',
#    'trigger': {'start': 333, 'end': 334, 'text': 'reported', 'sent_idx': 11},
# ...
